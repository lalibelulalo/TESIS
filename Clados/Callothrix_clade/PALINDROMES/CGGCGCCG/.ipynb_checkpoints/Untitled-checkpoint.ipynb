# %%
import re
import os
import sys

pattern = 'GCGATCGC'
pattern = re.sub('G', '[gG][-]*', pattern)
pattern = re.sub('C', '[cC][-]*', pattern)
pattern = re.sub('T', '[tT][-]*', pattern)
pattern = re.sub('A', '[aA][-]*', pattern)
pattern = pattern[:-4]
pattern
# Out:
# '[gG][-]*[cC][-]*[gG][-]*[aA][-]*[tT][-]*[cC][-]*[gG][-]*[cC]'

# %%
from Bio import SeqIO
import re
import os
import sys

SEQUENCES_PATH = sys.argv[1] #'Only_ORTHOLOGUES/' #
pattern = sys.argv[2] #'GCGATCGC' #
SPP = sys.argv[3] #'336-3' #
#SEQUENCES_PATH = 'gbff/Only_ORTHOLOGUES/' ## Path de la carpeta con los ortólogos.
output_file = 'Orthologues_Palindrome_sites.txt.test' ## Nombre del archivo de salida
output = open (output_file, 'w') ## Abrimos el archivo de salida
output.write('FILE\tPAL\tSTART\tEND\n')

if SEQUENCES_PATH.endswith("/"): ## Esta parte la pongo por si corro este codigo en la terminal
    SequencesPath = re.sub('/', '', SEQUENCES_PATH) ## De este modo evito errores en el argumento path 
    SequencesDir = str(SEQUENCES_PATH)
else:
    SequencesPath = SEQUENCES_PATH
    SequencesDir = str("".join ([SEQUENCES_PATH,'/']))
Orthologues = [x for x in os.listdir(SequencesDir) if x.endswith(".phy")] ## creo un arreglo con todos los ortólogis de la carpeta
#pattern = '[cC][-]*[gG][-]*[gG][-]*[cC][-]*[gG][-]*[cC][-]*[cC][-]*[gG]'
pattern = re.sub('G', '[gG][-]*', pattern)
pattern = re.sub('C', '[cC][-]*', pattern)
pattern = re.sub('T', '[tT][-]*', pattern)
pattern = re.sub('A', '[aA][-]*', pattern)
pattern = pattern[:-4]
#pattern
j=0
k=0
for Orthologue in Orthologues:
    FNA = str("".join ([SequencesDir,Orthologue])) ## creo el path completo con el path de la carpeta de ortólogos y el path del ortólogo
    for record in SeqIO.parse(open(FNA),'phylip'):
        Seq = str(record.seq)
        Spp = record.description
        i = 0
        if Spp == SPP:#PCC_6303_PCC_6303 336-3_336-3
            for match in re.finditer(pattern, Seq):
                i += 1
                j += 1
                site = match.group()
                start = match.span()[0]
                end = match.span()[1]
                if len(site)==8:
                    k += 1
                    print ('{}\t{}\t{}\t{}:{}'.format(i,Orthologue,site,start+1,end))
                    output.write('{}\t{}\t{}\t{}\n'.format(Orthologue,site,start+1,end))
    print ('_________________________________________________________________________\n')
output.close()
print ("TOTAL: {} sitios".format(k))
# Out:
# 1	9798_DUF3110_domain-conta...fna.awk1.mafft.phy	gcgatcgc	80:87
# _________________________________________________________________________
#
# 1	5385_lptB.fna.awk1.mafft.phy	gcgatcgc	557:564
# _________________________________________________________________________
#
# 1	5720_ABC_transporter_perm...fna.awk1.mafft.phy	gcgatcgc	262:269
# 2	5720_ABC_transporter_perm...fna.awk1.mafft.phy	gcgatcgc	853:860
# _________________________________________________________________________
#
# 1	9524_mtnA.fna.awk1.mafft.phy	gcgatcgc	784:791
# _________________________________________________________________________
#
# 1	7123_IctB_family_putative...fna.awk1.mafft.phy	gcgatcgc	139:146
# 2	7123_IctB_family_putative...fna.awk1.mafft.phy	gcgatcgc	438:445
# 3	7123_IctB_family_putative...fna.awk1.mafft.phy	gcgatcgc	772:779
# 4	7123_IctB_family_putative...fna.awk1.mafft.phy	gcgatcgc	1255:1262
# _________________________________________________________________________
#
# 1	9977_metG.fna.awk1.mafft.phy	gcgatcgc	1192:1199
# _________________________________________________________________________
#
# 1	5539_NAD-P--FAD-dependent...fna.awk1.mafft.phy	gcgatcgc	57:64
# 2	5539_NAD-P--FAD-dependent...fna.awk1.mafft.phy	gcgatcgc	487:494
# _________________________________________________________________________
#
# 1	9879_cysK.fna.awk1.mafft.phy	gcgatcgc	604:611
# 2	9879_cysK.fna.awk1.mafft.phy	gcgatcgc	751:758
# _________________________________________________________________________
#
# 1	8843_argH.fna.awk1.mafft.phy	gcgatcgc	58:65
# 2	8843_argH.fna.awk1.mafft.phy	gcgatcgc	701:708
# _________________________________________________________________________
#
# 1	8295_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	1446:1453
# 2	8295_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	1813:1820
# 3	8295_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	2433:2440
# 4	8295_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	2965:2972
# _________________________________________________________________________
#
# 1	7268_DEAD-DEAH_box_helica...fna.awk1.mafft.phy	gcgatcgc	1243:1250
# 2	7268_DEAD-DEAH_box_helica...fna.awk1.mafft.phy	gcgatcgc	1388:1395
# _________________________________________________________________________
#
# 1	8967_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	187:194
# 2	8967_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	305:312
# 3	8967_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	610:617
# 4	8967_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	933:940
# 5	8967_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	1089:1096
# 6	8967_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	1274:1281
# _________________________________________________________________________
#
# 1	6097_M61_family_metallope...fna.awk1.mafft.phy	gcgatcgc	1290:1297
# 2	6097_M61_family_metallope...fna.awk1.mafft.phy	gcgatcgc	1655:1662
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	7957_YaaW_family_protein.fna.awk1.mafft.phy	gcgatcgc	213:220
# 2	7957_YaaW_family_protein.fna.awk1.mafft.phy	gcgatcgc	484:491
# 3	7957_YaaW_family_protein.fna.awk1.mafft.phy	gcgatcgc	754:761
# _________________________________________________________________________
#
# 1	8169_devC.fna.awk1.mafft.phy	gcgatcgc	1166:1173
# _________________________________________________________________________
#
# 1	8978_uvrB.fna.awk1.mafft.phy	gcgatcgc	55:62
# 2	8978_uvrB.fna.awk1.mafft.phy	gcgatcgc	89:96
# 3	8978_uvrB.fna.awk1.mafft.phy	gcgatcgc	378:385
# _________________________________________________________________________
#
# 1	7299_alpha-D-glucose_phos...fna.awk1.mafft.phy	gcgatcgc	842:849
# _________________________________________________________________________
#
# 1	9889_DUF1822_family_prote...fna.awk1.mafft.phy	gcgatcgc	467:474
# _________________________________________________________________________
#
# 1	8595_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	251:258
# 2	8595_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	605:612
# 3	8595_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	679:686
# _________________________________________________________________________
#
# 1	6735_ABC_transporter_ATP-...fna.awk1.mafft.phy	gcgatcgc	320:327
# _________________________________________________________________________
#
# 1	7839_pantothenate_kinase.fna.awk1.mafft.phy	gcgatcgc	716:723
# _________________________________________________________________________
#
# 1	9356_ruvA.fna.awk1.mafft.phy	gcgatcgc	271:278
# _________________________________________________________________________
#
# 1	7989_YqeG_family_HAD_IIIA...fna.awk1.mafft.phy	gcgatcgc	356:363
# _________________________________________________________________________
#
# 1	9615_DEAD-DEAH_box_helica...fna.awk1.mafft.phy	gcgatcgc	856:863
# _________________________________________________________________________
#
# 1	7099_energy-coupling_fact...fna.awk1.mafft.phy	gcgatcgc	928:935
# _________________________________________________________________________
#
# 1	7728_tetratricopeptide_re...fna.awk1.mafft.phy	gcgatcgc	253:260
# 2	7728_tetratricopeptide_re...fna.awk1.mafft.phy	gcgatcgc	355:362
# 3	7728_tetratricopeptide_re...fna.awk1.mafft.phy	gcgatcgc	661:668
# _________________________________________________________________________
#
# 1	5493_murD.fna.awk1.mafft.phy	gcgatcgc	699:706
# 2	5493_murD.fna.awk1.mafft.phy	gcgatcgc	812:819
# _________________________________________________________________________
#
# 1	8610_Rne-Rng_family_ribon...fna.awk1.mafft.phy	gcgatcgc	758:765
# 2	8610_Rne-Rng_family_ribon...fna.awk1.mafft.phy	gcgatcgc	1711:1718
# _________________________________________________________________________
#
# 1	8008_phosphatidate_cytidy...fna.awk1.mafft.phy	gcgatcgc	49:56
# 2	8008_phosphatidate_cytidy...fna.awk1.mafft.phy	gcgatcgc	388:395
# _________________________________________________________________________
#
# 1	8336_thioester_reductase_...fna.awk1.mafft.phy	gcgatcgc	971:978
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9260_gcvP.fna.awk1.mafft.phy	gcgatcgc	50:57
# 2	9260_gcvP.fna.awk1.mafft.phy	gcgatcgc	648:655
# 3	9260_gcvP.fna.awk1.mafft.phy	gcgatcgc	2827:2834
# _________________________________________________________________________
#
# 1	9300_prfC.fna.awk1.mafft.phy	gcgatcgc	536:543
# 2	9300_prfC.fna.awk1.mafft.phy	gcgatcgc	944:951
# 3	9300_prfC.fna.awk1.mafft.phy	gcgatcgc	1585:1592
# _________________________________________________________________________
#
# 1	5471_lipid-A-disaccharide...fna.awk1.mafft.phy	gcgatcgc	97:104
# 2	5471_lipid-A-disaccharide...fna.awk1.mafft.phy	gcgatcgc	906:913
# 3	5471_lipid-A-disaccharide...fna.awk1.mafft.phy	gcgatcgc	1271:1278
# _________________________________________________________________________
#
# 1	9683_CHASE2_domain-contai...fna.awk1.mafft.phy	gcgatcgc	2007:2014
# 2	9683_CHASE2_domain-contai...fna.awk1.mafft.phy	gcgatcgc	2319:2326
# _________________________________________________________________________
#
# 1	6953_TatD_family_hydrolas...fna.awk1.mafft.phy	gcgatcgc	66:73
# 2	6953_TatD_family_hydrolas...fna.awk1.mafft.phy	gcgatcgc	349:356
# 3	6953_TatD_family_hydrolas...fna.awk1.mafft.phy	gcgatcgc	596:603
# 4	6953_TatD_family_hydrolas...fna.awk1.mafft.phy	gcgatcgc	730:737
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9905_cyclase_family_prote...fna.awk1.mafft.phy	gcgatcgc	556:563
# _________________________________________________________________________
#
# 1	6081_pre-16S_rRNA-process...fna.awk1.mafft.phy	gcgatcgc	302:309
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	7341_pentapeptide_repeat-...fna.awk1.mafft.phy	gcgatcgc	19:26
# 2	7341_pentapeptide_repeat-...fna.awk1.mafft.phy	gcgatcgc	79:86
# 3	7341_pentapeptide_repeat-...fna.awk1.mafft.phy	gcgatcgc	517:524
# _________________________________________________________________________
#
# 1	9283_TIGR00300_family_pro...fna.awk1.mafft.phy	gcgatcgc	101:108
# 2	9283_TIGR00300_family_pro...fna.awk1.mafft.phy	gcgatcgc	619:626
# 3	9283_TIGR00300_family_pro...fna.awk1.mafft.phy	gcgatcgc	1219:1226
# 4	9283_TIGR00300_family_pro...fna.awk1.mafft.phy	gcgatcgc	1573:1580
# 5	9283_TIGR00300_family_pro...fna.awk1.mafft.phy	gcgatcgc	1997:2004
# _________________________________________________________________________
#
# 1	8329_ABC_exporter_membran...fna.awk1.mafft.phy	gcgatcgc	452:459
# 2	8329_ABC_exporter_membran...fna.awk1.mafft.phy	gcgatcgc	935:942
# _________________________________________________________________________
#
# 1	7432_ABC_transporter_ATP-...fna.awk1.mafft.phy	gcgatcgc	172:179
# 2	7432_ABC_transporter_ATP-...fna.awk1.mafft.phy	gcgatcgc	1641:1648
# _________________________________________________________________________
#
# 1	9006_recN.fna.awk1.mafft.phy	gcgatcgc	371:378
# 2	9006_recN.fna.awk1.mafft.phy	gcgatcgc	852:859
# 3	9006_recN.fna.awk1.mafft.phy	gcgatcgc	1434:1441
# 4	9006_recN.fna.awk1.mafft.phy	gcgatcgc	1686:1693
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	7713_GTP-binding_protein.fna.awk1.mafft.phy	gcgatcgc	1006:1013
# _________________________________________________________________________
#
# 1	7672_glutamate-5-semialde...fna.awk1.mafft.phy	gcgatcgc	258:265
# 2	7672_glutamate-5-semialde...fna.awk1.mafft.phy	gcgatcgc	1008:1015
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9120_polA.fna.awk1.mafft.phy	gcgatcgc	305:312
# 2	9120_polA.fna.awk1.mafft.phy	gcgatcgc	479:486
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9565_crtD.fna.awk1.mafft.phy	gcgatcgc	733:740
# 2	9565_crtD.fna.awk1.mafft.phy	gcgatcgc	1239:1246
# 3	9565_crtD.fna.awk1.mafft.phy	gcgatcgc	1336:1343
# _________________________________________________________________________
#
# 1	7452_N-acetylmuramoyl-L-a...fna.awk1.mafft.phy	gcgatcgc	427:434
# 2	7452_N-acetylmuramoyl-L-a...fna.awk1.mafft.phy	gcgatcgc	1288:1295
# 3	7452_N-acetylmuramoyl-L-a...fna.awk1.mafft.phy	gcgatcgc	1825:1832
# _________________________________________________________________________
#
# 1	9992_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	43:50
# 2	9992_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	410:417
# 3	9992_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	694:701
# 4	9992_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	1435:1442
# _________________________________________________________________________
#
# 1	9007_SpoIID-LytB_domain-c...fna.awk1.mafft.phy	gcgatcgc	299:306
# 2	9007_SpoIID-LytB_domain-c...fna.awk1.mafft.phy	gcgatcgc	1098:1105
# _________________________________________________________________________
#
# 1	9724_methyltransferase_do...fna.awk1.mafft.phy	gcgatcgc	616:623
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9597_aminotransferase_cla...fna.awk1.mafft.phy	gcgatcgc	367:374
# 2	9597_aminotransferase_cla...fna.awk1.mafft.phy	gcgatcgc	553:560
# 3	9597_aminotransferase_cla...fna.awk1.mafft.phy	gcgatcgc	752:759
# _________________________________________________________________________
#
# 1	6562_response_regulator.fna.awk1.mafft.phy	gcgatcgc	287:294
# _________________________________________________________________________
#
# 1	5710_aldo-keto_reductase.fna.awk1.mafft.phy	gcgatcgc	238:245
# _________________________________________________________________________
#
# 1	9310_metH.fna.awk1.mafft.phy	gcgatcgc	445:452
# 2	9310_metH.fna.awk1.mafft.phy	gcgatcgc	557:564
# 3	9310_metH.fna.awk1.mafft.phy	gcgatcgc	1113:1120
# _________________________________________________________________________
#
# 1	8267_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	673:680
# _________________________________________________________________________
#
# 1	8728_DUF697_domain-contai...fna.awk1.mafft.phy	gcgatcgc	228:235
# 2	8728_DUF697_domain-contai...fna.awk1.mafft.phy	gcgatcgc	953:960
# _________________________________________________________________________
#
# 1	5994_aldehyde_dehydrogena...fna.awk1.mafft.phy	gcgatcgc	148:155
# 2	5994_aldehyde_dehydrogena...fna.awk1.mafft.phy	gcgatcgc	793:800
# _________________________________________________________________________
#
# 1	6229_purM.fna.awk1.mafft.phy	gcgatcgc	523:530
# _________________________________________________________________________
#
# 1	9174_aspartate_aminotrans...fna.awk1.mafft.phy	gcgatcgc	928:935
# 2	9174_aspartate_aminotrans...fna.awk1.mafft.phy	gcgatcgc	1021:1028
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9560_RNA_polymerase_sigma...fna.awk1.mafft.phy	gcgatcgc	478:485
# _________________________________________________________________________
#
# 1	7649_ccsB.fna.awk1.mafft.phy	gcgatcgc	145:152
# 2	7649_ccsB.fna.awk1.mafft.phy	gcgatcgc	478:485
# _________________________________________________________________________
#
# 1	6688_NADP-dependent_isoci...fna.awk1.mafft.phy	gcgatcgc	1312:1319
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8158_transporter_substrat...fna.awk1.mafft.phy	gcgatcgc	342:349
# 2	8158_transporter_substrat...fna.awk1.mafft.phy	gcgatcgc	610:617
# 3	8158_transporter_substrat...fna.awk1.mafft.phy	gcgatcgc	791:798
# _________________________________________________________________________
#
# 1	7098_der.fna.awk1.mafft.phy	gcgatcgc	116:123
# 2	7098_der.fna.awk1.mafft.phy	gcgatcgc	146:153
# _________________________________________________________________________
#
# 2	9428_tetratricopeptide_re...fna.awk1.mafft.phy	gcgatcgc	1016:1023
# 3	9428_tetratricopeptide_re...fna.awk1.mafft.phy	gcgatcgc	1622:1629
# _________________________________________________________________________
#
# 1	7716_polyketide_cyclase_-...fna.awk1.mafft.phy	gcgatcgc	422:429
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8965_FAD-dependent_hydrox...fna.awk1.mafft.phy	gcgatcgc	854:861
# 2	8965_FAD-dependent_hydrox...fna.awk1.mafft.phy	gcgatcgc	890:897
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8954_LL-diaminopimelate_a...fna.awk1.mafft.phy	gcgatcgc	191:198
# _________________________________________________________________________
#
# 1	7307_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	690:697
# 2	7307_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	837:844
# 3	7307_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	1470:1477
# 4	7307_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	2054:2061
# _________________________________________________________________________
#
# 1	9066_glycerol_acyltransfe...fna.awk1.mafft.phy	gcgatcgc	667:674
# 2	9066_glycerol_acyltransfe...fna.awk1.mafft.phy	gcgatcgc	943:950
# 3	9066_glycerol_acyltransfe...fna.awk1.mafft.phy	gcgatcgc	1130:1137
# 4	9066_glycerol_acyltransfe...fna.awk1.mafft.phy	gcgatcgc	1367:1374
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8783_gatA.fna.awk1.mafft.phy	gcgatcgc	673:680
# _________________________________________________________________________
#
# 1	7861_serine-threonine-pro...fna.awk1.mafft.phy	gcgatcgc	775:782
# _________________________________________________________________________
#
# 1	7449_ROK_family_protein.fna.awk1.mafft.phy	gcgatcgc	157:164
# 2	7449_ROK_family_protein.fna.awk1.mafft.phy	gcgatcgc	769:776
# _________________________________________________________________________
#
# 1	6998_YifB_family_Mg_chela...fna.awk1.mafft.phy	gcgatcgc	803:810
# 2	6998_YifB_family_Mg_chela...fna.awk1.mafft.phy	gcgatcgc	1418:1425
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	5949_adenylate_kinase.fna.awk1.mafft.phy	gcgatcgc	476:483
# 2	5949_adenylate_kinase.fna.awk1.mafft.phy	gcgatcgc	547:554
# _________________________________________________________________________
#
# 1	9265_ilvB.fna.awk1.mafft.phy	gcgatcgc	746:753
# 2	9265_ilvB.fna.awk1.mafft.phy	gcgatcgc	1673:1680
# _________________________________________________________________________
#
# 1	6663_ribulose_bisphosphat...fna.awk1.mafft.phy	gcgatcgc	663:670
# _________________________________________________________________________
#
# 1	6855_polysaccharide_biosy...fna.awk1.mafft.phy	gcgatcgc	612:619
# 2	6855_polysaccharide_biosy...fna.awk1.mafft.phy	gcgatcgc	790:797
# 3	6855_polysaccharide_biosy...fna.awk1.mafft.phy	gcgatcgc	2284:2291
# _________________________________________________________________________
#
# 1	8851_NAD-P-H-quinone_oxid...fna.awk1.mafft.phy	gcgatcgc	626:633
# 2	8851_NAD-P-H-quinone_oxid...fna.awk1.mafft.phy	gcgatcgc	1822:1829
# _________________________________________________________________________
#
# 1	9173_potassium_channel_pr...fna.awk1.mafft.phy	gcgatcgc	628:635
# _________________________________________________________________________
#
# 1	9141_trypsin-like_peptida...fna.awk1.mafft.phy	gcgatcgc	125:132
# 2	9141_trypsin-like_peptida...fna.awk1.mafft.phy	gcgatcgc	1102:1109
# _________________________________________________________________________
#
# 1	8598_phosphodiester_glyco...fna.awk1.mafft.phy	gcgatcgc	1485:1492
# 2	8598_phosphodiester_glyco...fna.awk1.mafft.phy	gcgatcgc	1645:1652
# _________________________________________________________________________
#
# 1	9457_FAD-binding_oxidored...fna.awk1.mafft.phy	gcgatcgc	43:50
# 2	9457_FAD-binding_oxidored...fna.awk1.mafft.phy	gcgatcgc	1140:1147
# _________________________________________________________________________
#
# 1	5512_AAA_family_ATPase.fna.awk1.mafft.phy	gcgatcgc	292:299
# 2	5512_AAA_family_ATPase.fna.awk1.mafft.phy	gcgatcgc	565:572
# 3	5512_AAA_family_ATPase.fna.awk1.mafft.phy	gcgatcgc	832:839
# _________________________________________________________________________
#
# 1	9842_lpdA.fna.awk1.mafft.phy	gcgatcgc	259:266
# 2	9842_lpdA.fna.awk1.mafft.phy	gcgatcgc	1324:1331
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	7555_ergothioneine_biosyn...fna.awk1.mafft.phy	gcgatcgc	73:80
# _________________________________________________________________________
#
# 1	6954_rpoB.fna.awk1.mafft.phy	gcgatcgc	384:391
# _________________________________________________________________________
#
# 1	5352_secA.fna.awk1.mafft.phy	gcgatcgc	1240:1247
# 2	5352_secA.fna.awk1.mafft.phy	gcgatcgc	2057:2064
# _________________________________________________________________________
#
# 1	9947_ferredoxin-protochlo...fna.awk1.mafft.phy	gcgatcgc	281:288
# _________________________________________________________________________
#
# 1	7284_dnaJ.fna.awk1.mafft.phy	gcgatcgc	1091:1098
# _________________________________________________________________________
#
# 1	7420_ferredoxin.fna.awk1.mafft.phy	gcgatcgc	228:235
# _________________________________________________________________________
#
# 1	8089_CHAD_domain-containi...fna.awk1.mafft.phy	gcgatcgc	224:231
# _________________________________________________________________________
#
# 1	6679_class_I_SAM-dependen...fna.awk1.mafft.phy	gcgatcgc	42:49
# _________________________________________________________________________
#
# 1	6338_ATP-binding_cassette...fna.awk1.mafft.phy	gcgatcgc	260:267
# 2	6338_ATP-binding_cassette...fna.awk1.mafft.phy	gcgatcgc	628:635
# 3	6338_ATP-binding_cassette...fna.awk1.mafft.phy	gcgatcgc	791:798
# _________________________________________________________________________
#
# 1	6779_rhomboid_family_intr...fna.awk1.mafft.phy	gcgatcgc	175:182
# 2	6779_rhomboid_family_intr...fna.awk1.mafft.phy	gcgatcgc	445:452
# _________________________________________________________________________
#
# 1	6094_miaA.fna.awk1.mafft.phy	gcgatcgc	196:203
# 2	6094_miaA.fna.awk1.mafft.phy	gcgatcgc	504:511
# 3	6094_miaA.fna.awk1.mafft.phy	gcgatcgc	568:575
# _________________________________________________________________________
#
# 1	9278_YegS-Rv2252-BmrU_fam...fna.awk1.mafft.phy	gcgatcgc	688:695
# _________________________________________________________________________
#
# 1	9498_lysS.fna.awk1.mafft.phy	gcgatcgc	166:173
# 2	9498_lysS.fna.awk1.mafft.phy	gcgatcgc	1465:1472
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	5611_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	857:864
# 2	5611_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	3144:3151
# 3	5611_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	3385:3392
# 4	5611_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	3893:3900
# 5	5611_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	4517:4524
# _________________________________________________________________________
#
# 1	8723_glycosyltransferase_...fna.awk1.mafft.phy	gcgatcgc	966:973
# _________________________________________________________________________
#
# 1	9887_pruA.fna.awk1.mafft.phy	gcgatcgc	683:690
# 2	9887_pruA.fna.awk1.mafft.phy	gcgatcgc	1033:1040
# 3	9887_pruA.fna.awk1.mafft.phy	gcgatcgc	1114:1121
# 4	9887_pruA.fna.awk1.mafft.phy	gcgatcgc	1961:1968
# 5	9887_pruA.fna.awk1.mafft.phy	gcgatcgc	2633:2640
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 2	7221_hisD.fna.awk1.mafft.phy	gcgatcgc	661:668
# _________________________________________________________________________
#
# 1	5461_leuS.fna.awk1.mafft.phy	gcgatcgc	181:188
# 2	5461_leuS.fna.awk1.mafft.phy	gcgatcgc	324:331
# _________________________________________________________________________
#
# 1	9682_ABC_transporter_subs...fna.awk1.mafft.phy	gcgatcgc	499:506
# _________________________________________________________________________
#
# 1	8000_argS.fna.awk1.mafft.phy	gcgatcgc	178:185
# 2	8000_argS.fna.awk1.mafft.phy	gcgatcgc	433:440
# 3	8000_argS.fna.awk1.mafft.phy	gcgatcgc	1201:1208
# _________________________________________________________________________
#
# 1	7339_mutL.fna.awk1.mafft.phy	gcgatcgc	451:458
# 2	7339_mutL.fna.awk1.mafft.phy	gcgatcgc	920:927
# _________________________________________________________________________
#
# 1	5646_GTP-binding_protein.fna.awk1.mafft.phy	gcgatcgc	841:848
# 2	5646_GTP-binding_protein.fna.awk1.mafft.phy	gcgatcgc	1489:1496
# _________________________________________________________________________
#
# 1	7148_adenylosuccinate_syn...fna.awk1.mafft.phy	gcgatcgc	1049:1056
# _________________________________________________________________________
#
# 1	6785_sulfate_ABC_transpor...fna.awk1.mafft.phy	gcgatcgc	127:134
# _________________________________________________________________________
#
# 1	6747_serine_hydroxymethyl...fna.awk1.mafft.phy	gcgatcgc	1229:1236
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8019_ATP-binding_protein.fna.awk1.mafft.phy	gcgatcgc	55:62
# 2	8019_ATP-binding_protein.fna.awk1.mafft.phy	gcgatcgc	1973:1980
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9715_serine-threonine_pro...fna.awk1.mafft.phy	gcgatcgc	1694:1701
# _________________________________________________________________________
#
# 1	8806_bifunctional_-p-ppGp...fna.awk1.mafft.phy	gcgatcgc	1982:1989
# 2	8806_bifunctional_-p-ppGp...fna.awk1.mafft.phy	gcgatcgc	2198:2205
# _________________________________________________________________________
#
# 1	6720_NAD-P-H-quinone_oxid...fna.awk1.mafft.phy	gcgatcgc	425:432
# _________________________________________________________________________
#
# 1	8043_aspartate_carbamoylt...fna.awk1.mafft.phy	gcgatcgc	388:395
# _________________________________________________________________________
#
# 1	6709_alpha-mannosidase.fna.awk1.mafft.phy	gcgatcgc	468:475
# 2	6709_alpha-mannosidase.fna.awk1.mafft.phy	gcgatcgc	680:687
# 3	6709_alpha-mannosidase.fna.awk1.mafft.phy	gcgatcgc	1223:1230
# 4	6709_alpha-mannosidase.fna.awk1.mafft.phy	gcgatcgc	1947:1954
# 5	6709_alpha-mannosidase.fna.awk1.mafft.phy	gcgatcgc	2030:2037
# _________________________________________________________________________
#
# 1	6947_fatty_acid_desaturas...fna.awk1.mafft.phy	gcgatcgc	636:643
# 2	6947_fatty_acid_desaturas...fna.awk1.mafft.phy	gcgatcgc	798:805
# _________________________________________________________________________
#
# 1	6155_S8_family_serine_pep...fna.awk1.mafft.phy	gcgatcgc	1337:1344
# 2	6155_S8_family_serine_pep...fna.awk1.mafft.phy	gcgatcgc	2153:2160
# _________________________________________________________________________
#
# 1	8816_typA.fna.awk1.mafft.phy	gcgatcgc	995:1002
# _________________________________________________________________________
#
# 1	9764_serine-threonine_pro...fna.awk1.mafft.phy	gcgatcgc	579:586
# 2	9764_serine-threonine_pro...fna.awk1.mafft.phy	gcgatcgc	665:672
# 3	9764_serine-threonine_pro...fna.awk1.mafft.phy	gcgatcgc	1055:1062
# 4	9764_serine-threonine_pro...fna.awk1.mafft.phy	gcgatcgc	1562:1569
# _________________________________________________________________________
#
# 1	7816_M48_family_metallope...fna.awk1.mafft.phy	gcgatcgc	545:552
# _________________________________________________________________________
#
# 1	7899_SGNH-GDSL_hydrolase_...fna.awk1.mafft.phy	gcgatcgc	75:82
# 2	7899_SGNH-GDSL_hydrolase_...fna.awk1.mafft.phy	gcgatcgc	518:525
# 3	7899_SGNH-GDSL_hydrolase_...fna.awk1.mafft.phy	gcgatcgc	632:639
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9251_cofH.fna.awk1.mafft.phy	gcgatcgc	112:119
# 2	9251_cofH.fna.awk1.mafft.phy	gcgatcgc	735:742
# 3	9251_cofH.fna.awk1.mafft.phy	gcgatcgc	1084:1091
# _________________________________________________________________________
#
# 1	6468_def.fna.awk1.mafft.phy	gcgatcgc	68:75
# _________________________________________________________________________
#
# 1	9064_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	618:625
# _________________________________________________________________________
#
# 1	5728_competence-damage-in...fna.awk1.mafft.phy	gcgatcgc	1178:1185
# _________________________________________________________________________
#
# 1	7334_glycosyltransferase_...fna.awk1.mafft.phy	gcgatcgc	278:285
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	5921_PilT-PilU_family_typ...fna.awk1.mafft.phy	gcgatcgc	805:812
# 2	5921_PilT-PilU_family_typ...fna.awk1.mafft.phy	gcgatcgc	885:892
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8289_arsJ.fna.awk1.mafft.phy	gcgatcgc	913:920
# _________________________________________________________________________
#
# 1	7502_GNAT_family_N-acetyl...fna.awk1.mafft.phy	gcgatcgc	197:204
# 2	7502_GNAT_family_N-acetyl...fna.awk1.mafft.phy	gcgatcgc	964:971
# _________________________________________________________________________
#
# 1	9584_glutamyl-tRNA_reduct...fna.awk1.mafft.phy	gcgatcgc	91:98
# 2	9584_glutamyl-tRNA_reduct...fna.awk1.mafft.phy	gcgatcgc	1011:1018
# _________________________________________________________________________
#
# 1	7412_hemW.fna.awk1.mafft.phy	gcgatcgc	107:114
# 2	7412_hemW.fna.awk1.mafft.phy	gcgatcgc	438:445
# _________________________________________________________________________
#
# 1	7840_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	98:105
# _________________________________________________________________________
#
# 1	8367_ribonuclease_R.fna.awk1.mafft.phy	gcgatcgc	311:318
# 2	8367_ribonuclease_R.fna.awk1.mafft.phy	gcgatcgc	1010:1017
# 3	8367_ribonuclease_R.fna.awk1.mafft.phy	gcgatcgc	1356:1363
# 4	8367_ribonuclease_R.fna.awk1.mafft.phy	gcgatcgc	1769:1776
# 5	8367_ribonuclease_R.fna.awk1.mafft.phy	gcgatcgc	2237:2244
# _________________________________________________________________________
#
# 1	6463_sigma_54-interacting...fna.awk1.mafft.phy	gcgatcgc	79:86
# 2	6463_sigma_54-interacting...fna.awk1.mafft.phy	gcgatcgc	449:456
# 3	6463_sigma_54-interacting...fna.awk1.mafft.phy	gcgatcgc	1348:1355
# _________________________________________________________________________
#
# 1	7684_cyanophycinase.fna.awk1.mafft.phy	gcgatcgc	803:810
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9873_prmC.fna.awk1.mafft.phy	gcgatcgc	76:83
# 2	9873_prmC.fna.awk1.mafft.phy	gcgatcgc	427:434
# 3	9873_prmC.fna.awk1.mafft.phy	gcgatcgc	502:509
# 4	9873_prmC.fna.awk1.mafft.phy	gcgatcgc	539:546
# _________________________________________________________________________
#
# 1	7185_sulfite_exporter_Tau...fna.awk1.mafft.phy	gcgatcgc	271:278
# 2	7185_sulfite_exporter_Tau...fna.awk1.mafft.phy	gcgatcgc	925:932
# _________________________________________________________________________
#
# 1	5472_BamA-TamA_family_out...fna.awk1.mafft.phy	gcgatcgc	999:1006
# 2	5472_BamA-TamA_family_out...fna.awk1.mafft.phy	gcgatcgc	1544:1551
# 3	5472_BamA-TamA_family_out...fna.awk1.mafft.phy	gcgatcgc	1844:1851
# _________________________________________________________________________
#
# 1	7551_TM0106_family_RecB-l...fna.awk1.mafft.phy	gcgatcgc	855:862
# 2	7551_TM0106_family_RecB-l...fna.awk1.mafft.phy	gcgatcgc	1632:1639
# _________________________________________________________________________
#
# 2	6071_serine-threonine_pro...fna.awk1.mafft.phy	gcgatcgc	750:757
# _________________________________________________________________________
#
# 1	7016_hisIE.fna.awk1.mafft.phy	gcgatcgc	407:414
# 2	7016_hisIE.fna.awk1.mafft.phy	gcgatcgc	541:548
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9301_M48_family_metallopr...fna.awk1.mafft.phy	gcgatcgc	181:188
# 2	9301_M48_family_metallopr...fna.awk1.mafft.phy	gcgatcgc	1185:1192
# 3	9301_M48_family_metallopr...fna.awk1.mafft.phy	gcgatcgc	1210:1217
# 4	9301_M48_family_metallopr...fna.awk1.mafft.phy	gcgatcgc	1308:1315
# 5	9301_M48_family_metallopr...fna.awk1.mafft.phy	gcgatcgc	1581:1588
# 6	9301_M48_family_metallopr...fna.awk1.mafft.phy	gcgatcgc	2246:2253
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	6455_phosphoglucomutase-p...fna.awk1.mafft.phy	gcgatcgc	638:645
# 2	6455_phosphoglucomutase-p...fna.awk1.mafft.phy	gcgatcgc	776:783
# _________________________________________________________________________
#
# 1	9626_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	833:840
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9904_insulinase_family_pr...fna.awk1.mafft.phy	gcgatcgc	1054:1061
# 2	9904_insulinase_family_pr...fna.awk1.mafft.phy	gcgatcgc	1166:1173
# _________________________________________________________________________
#
# 1	7857_penicillin-binding_p...fna.awk1.mafft.phy	gcgatcgc	311:318
# 2	7857_penicillin-binding_p...fna.awk1.mafft.phy	gcgatcgc	1361:1368
# 3	7857_penicillin-binding_p...fna.awk1.mafft.phy	gcgatcgc	2259:2266
# _________________________________________________________________________
#
# 1	9937_carB.fna.awk1.mafft.phy	gcgatcgc	469:476
# 2	9937_carB.fna.awk1.mafft.phy	gcgatcgc	1232:1239
# 3	9937_carB.fna.awk1.mafft.phy	gcgatcgc	1490:1497
# 4	9937_carB.fna.awk1.mafft.phy	gcgatcgc	2379:2386
# _________________________________________________________________________
#
# 1	6694_RNA_methyltransferas...fna.awk1.mafft.phy	gcgatcgc	221:228
# 2	6694_RNA_methyltransferas...fna.awk1.mafft.phy	gcgatcgc	259:266
# 3	6694_RNA_methyltransferas...fna.awk1.mafft.phy	gcgatcgc	739:746
# _________________________________________________________________________
#
# 1	9775_DUF3536_domain-conta...fna.awk1.mafft.phy	gcgatcgc	421:428
# 2	9775_DUF3536_domain-conta...fna.awk1.mafft.phy	gcgatcgc	1271:1278
# 3	9775_DUF3536_domain-conta...fna.awk1.mafft.phy	gcgatcgc	2264:2271
# 4	9775_DUF3536_domain-conta...fna.awk1.mafft.phy	gcgatcgc	2344:2351
# _________________________________________________________________________
#
# 1	9143_dnaA.fna.awk1.mafft.phy	gcgatcgc	1377:1384
# _________________________________________________________________________
#
# 1	6489_accC.fna.awk1.mafft.phy	gcgatcgc	439:446
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	6703_purE.fna.awk1.mafft.phy	gcgatcgc	67:74
# _________________________________________________________________________
#
# 1	8309_SLBB_domain-containi...fna.awk1.mafft.phy	gcgatcgc	40:47
# 2	8309_SLBB_domain-containi...fna.awk1.mafft.phy	gcgatcgc	200:207
# _________________________________________________________________________
#
# 1	9506_bchH.fna.awk1.mafft.phy	gcgatcgc	113:120
# 2	9506_bchH.fna.awk1.mafft.phy	gcgatcgc	221:228
# 3	9506_bchH.fna.awk1.mafft.phy	gcgatcgc	1614:1621
# _________________________________________________________________________
#
# 1	7837_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	349:356
# 2	7837_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	1198:1205
# 3	7837_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	1227:1234
# 4	7837_GAF_domain-containin...fna.awk1.mafft.phy	gcgatcgc	1661:1668
# _________________________________________________________________________
#
# 1	8310_ABC_transporter_ATP-...fna.awk1.mafft.phy	gcgatcgc	275:282
# 2	8310_ABC_transporter_ATP-...fna.awk1.mafft.phy	gcgatcgc	674:681
# _________________________________________________________________________
#
# 1	7575_hemolysin_family_pro...fna.awk1.mafft.phy	gcgatcgc	120:127
# 2	7575_hemolysin_family_pro...fna.awk1.mafft.phy	gcgatcgc	163:170
# _________________________________________________________________________
#
# 1	9036_tgt.fna.awk1.mafft.phy	gcgatcgc	775:782
# 2	9036_tgt.fna.awk1.mafft.phy	gcgatcgc	969:976
# _________________________________________________________________________
#
# 1	5911_SDR_family_oxidoredu...fna.awk1.mafft.phy	gcgatcgc	208:215
# 2	5911_SDR_family_oxidoredu...fna.awk1.mafft.phy	gcgatcgc	412:419
# 3	5911_SDR_family_oxidoredu...fna.awk1.mafft.phy	gcgatcgc	619:626
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9410_FAD-dependent_oxidor...fna.awk1.mafft.phy	gcgatcgc	544:551
# _________________________________________________________________________
#
# 1	5747_YihY-virulence_facto...fna.awk1.mafft.phy	gcgatcgc	272:279
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9481_cob-I-yrinic_acid_a-...fna.awk1.mafft.phy	gcgatcgc	223:230
# 2	9481_cob-I-yrinic_acid_a-...fna.awk1.mafft.phy	gcgatcgc	361:368
# 3	9481_cob-I-yrinic_acid_a-...fna.awk1.mafft.phy	gcgatcgc	886:893
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	6574_glucokinase.fna.awk1.mafft.phy	gcgatcgc	196:203
# 2	6574_glucokinase.fna.awk1.mafft.phy	gcgatcgc	626:633
# 3	6574_glucokinase.fna.awk1.mafft.phy	gcgatcgc	761:768
# _________________________________________________________________________
#
# 1	7100_nadC.fna.awk1.mafft.phy	gcgatcgc	86:93
# 2	7100_nadC.fna.awk1.mafft.phy	gcgatcgc	570:577
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8549_AarF-ABC1-UbiB_kinas...fna.awk1.mafft.phy	gcgatcgc	1019:1026
# 2	8549_AarF-ABC1-UbiB_kinas...fna.awk1.mafft.phy	gcgatcgc	1054:1061
# 3	8549_AarF-ABC1-UbiB_kinas...fna.awk1.mafft.phy	gcgatcgc	1603:1610
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	6515_radA.fna.awk1.mafft.phy	gcgatcgc	239:246
# 2	6515_radA.fna.awk1.mafft.phy	gcgatcgc	880:887
# 3	6515_radA.fna.awk1.mafft.phy	gcgatcgc	938:945
# 4	6515_radA.fna.awk1.mafft.phy	gcgatcgc	1336:1343
# _________________________________________________________________________
#
# 1	9512_ABC_transporter_perm...fna.awk1.mafft.phy	gcgatcgc	520:527
# _________________________________________________________________________
#
# 1	9002_HAMP_domain-containi...fna.awk1.mafft.phy	gcgatcgc	1444:1451
# _________________________________________________________________________
#
# 1	5634_glgA.fna.awk1.mafft.phy	gcgatcgc	932:939
# _________________________________________________________________________
#
# 1	7147_creatininase_family_...fna.awk1.mafft.phy	gcgatcgc	136:143
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	6297_YdcF_family_protein.fna.awk1.mafft.phy	gcgatcgc	183:190
# 2	6297_YdcF_family_protein.fna.awk1.mafft.phy	gcgatcgc	308:315
# 3	6297_YdcF_family_protein.fna.awk1.mafft.phy	gcgatcgc	579:586
# 4	6297_YdcF_family_protein.fna.awk1.mafft.phy	gcgatcgc	616:623
# _________________________________________________________________________
#
# 1	7459_transglycosylase_dom...fna.awk1.mafft.phy	gcgatcgc	182:189
# 2	7459_transglycosylase_dom...fna.awk1.mafft.phy	gcgatcgc	1191:1198
# 3	7459_transglycosylase_dom...fna.awk1.mafft.phy	gcgatcgc	1858:1865
# _________________________________________________________________________
#
# 1	6702_nagA.fna.awk1.mafft.phy	gcgatcgc	360:367
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	5680_GDP-L-fucose_synthas...fna.awk1.mafft.phy	gcgatcgc	123:130
# _________________________________________________________________________
#
# 1	5413_heme_oxygenase_-bili...fna.awk1.mafft.phy	gcgatcgc	557:564
# _________________________________________________________________________
#
# 1	9494_glycerol-3-phosphate...fna.awk1.mafft.phy	gcgatcgc	407:414
# 2	9494_glycerol-3-phosphate...fna.awk1.mafft.phy	gcgatcgc	923:930
# 3	9494_glycerol-3-phosphate...fna.awk1.mafft.phy	gcgatcgc	996:1003
# 4	9494_glycerol-3-phosphate...fna.awk1.mafft.phy	gcgatcgc	1972:1979
# 5	9494_glycerol-3-phosphate...fna.awk1.mafft.phy	gcgatcgc	2524:2531
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8795_hrcA.fna.awk1.mafft.phy	gcgatcgc	1032:1039
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8562_peptidoglycan_DD-met...fna.awk1.mafft.phy	gcgatcgc	1146:1153
# 2	8562_peptidoglycan_DD-met...fna.awk1.mafft.phy	gcgatcgc	1510:1517
# _________________________________________________________________________
#
# 1	6171_cytochrome_c_oxidase...fna.awk1.mafft.phy	gcgatcgc	962:969
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8691_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	328:335
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	5989_rimI.fna.awk1.mafft.phy	gcgatcgc	509:516
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	7046_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	970:977
# 2	7046_hypothetical_protein.fna.awk1.mafft.phy	gcgatcgc	1118:1125
# _________________________________________________________________________
#
# 1	7824_NAD-P-H-dependent_gl...fna.awk1.mafft.phy	gcgatcgc	424:431
# 2	7824_NAD-P-H-dependent_gl...fna.awk1.mafft.phy	gcgatcgc	526:533
# _________________________________________________________________________
#
# 1	9752_16S_rRNA_-cytosine-9...fna.awk1.mafft.phy	gcgatcgc	143:150
# _________________________________________________________________________
#
# 1	9357_rpiA.fna.awk1.mafft.phy	gcgatcgc	134:141
# _________________________________________________________________________
#
# 1	6635_ankyrin_repeat_domai...fna.awk1.mafft.phy	gcgatcgc	222:229
# 2	6635_ankyrin_repeat_domai...fna.awk1.mafft.phy	gcgatcgc	733:740
# _________________________________________________________________________
#
# 1	6087_dxr.fna.awk1.mafft.phy	gcgatcgc	1061:1068
# _________________________________________________________________________
#
# 1	7862_serine-threonine_pho...fna.awk1.mafft.phy	gcgatcgc	1142:1149
# _________________________________________________________________________
#
# 1	8153_AI-2E_family_transpo...fna.awk1.mafft.phy	gcgatcgc	754:761
# _________________________________________________________________________
#
# 1	8684_site-2_protease_fami...fna.awk1.mafft.phy	gcgatcgc	1273:1280
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	7041_SDR_family_oxidoredu...fna.awk1.mafft.phy	gcgatcgc	911:918
# _________________________________________________________________________
#
# 1	9899_ftsE.fna.awk1.mafft.phy	gcgatcgc	350:357
# _________________________________________________________________________
#
# 1	9836_ispE.fna.awk1.mafft.phy	gcgatcgc	451:458
# _________________________________________________________________________
#
# 1	8693_alaS.fna.awk1.mafft.phy	gcgatcgc	322:329
# 2	8693_alaS.fna.awk1.mafft.phy	gcgatcgc	2138:2145
# 3	8693_alaS.fna.awk1.mafft.phy	gcgatcgc	2269:2276
# 4	8693_alaS.fna.awk1.mafft.phy	gcgatcgc	2605:2612
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	6922_aspS.fna.awk1.mafft.phy	gcgatcgc	116:123
# 2	6922_aspS.fna.awk1.mafft.phy	gcgatcgc	410:417
# 3	6922_aspS.fna.awk1.mafft.phy	gcgatcgc	952:959
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9157_mannose-1-phosphate_...fna.awk1.mafft.phy	gcgatcgc	1542:1549
# 2	9157_mannose-1-phosphate_...fna.awk1.mafft.phy	gcgatcgc	2202:2209
# _________________________________________________________________________
#
# 1	6205_ABC_transporter_perm...fna.awk1.mafft.phy	gcgatcgc	337:344
# 2	6205_ABC_transporter_perm...fna.awk1.mafft.phy	gcgatcgc	938:945
# _________________________________________________________________________
#
# 1	7676_WD40_repeat_domain-c...fna.awk1.mafft.phy	gcgatcgc	187:194
# 2	7676_WD40_repeat_domain-c...fna.awk1.mafft.phy	gcgatcgc	1579:1586
# _________________________________________________________________________
#
# 1	9290_PAS_domain_S-box_pro...fna.awk1.mafft.phy	gcgatcgc	791:798
# 2	9290_PAS_domain_S-box_pro...fna.awk1.mafft.phy	gcgatcgc	957:964
# 3	9290_PAS_domain_S-box_pro...fna.awk1.mafft.phy	gcgatcgc	1322:1329
# 5	9290_PAS_domain_S-box_pro...fna.awk1.mafft.phy	gcgatcgc	1962:1969
# 6	9290_PAS_domain_S-box_pro...fna.awk1.mafft.phy	gcgatcgc	2765:2772
# 7	9290_PAS_domain_S-box_pro...fna.awk1.mafft.phy	gcgatcgc	3148:3155
# 8	9290_PAS_domain_S-box_pro...fna.awk1.mafft.phy	gcgatcgc	3848:3855
# _________________________________________________________________________
#
# 1	6139_tetratricopeptide_re...fna.awk1.mafft.phy	gcgatcgc	465:472
# 2	6139_tetratricopeptide_re...fna.awk1.mafft.phy	gcgatcgc	851:858
# _________________________________________________________________________
#
# 1	8438_HesA-MoeB-ThiF_famil...fna.awk1.mafft.phy	gcgatcgc	710:717
# _________________________________________________________________________
#
# 1	7297_Hsp70_family_protein.fna.awk1.mafft.phy	gcgatcgc	4:11
# 2	7297_Hsp70_family_protein.fna.awk1.mafft.phy	gcgatcgc	191:198
# 3	7297_Hsp70_family_protein.fna.awk1.mafft.phy	gcgatcgc	1117:1124
# 4	7297_Hsp70_family_protein.fna.awk1.mafft.phy	gcgatcgc	1376:1383
# 5	7297_Hsp70_family_protein.fna.awk1.mafft.phy	gcgatcgc	1453:1460
# 6	7297_Hsp70_family_protein.fna.awk1.mafft.phy	gcgatcgc	1490:1497
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8165_GH116_family_glycosy...fna.awk1.mafft.phy	gcgatcgc	162:169
# 2	8165_GH116_family_glycosy...fna.awk1.mafft.phy	gcgatcgc	1084:1091
# 3	8165_GH116_family_glycosy...fna.awk1.mafft.phy	gcgatcgc	1825:1832
# 4	8165_GH116_family_glycosy...fna.awk1.mafft.phy	gcgatcgc	2069:2076
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8833_plsY.fna.awk1.mafft.phy	gcgatcgc	502:509
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	7493_sugar_transferase.fna.awk1.mafft.phy	gcgatcgc	505:512
# _________________________________________________________________________
#
# 1	6307_ftsY.fna.awk1.mafft.phy	gcgatcgc	1090:1097
# 2	6307_ftsY.fna.awk1.mafft.phy	gcgatcgc	1411:1418
# _________________________________________________________________________
#
# 1	8086_aminopeptidase_P_N-t...fna.awk1.mafft.phy	gcgatcgc	383:390
# 2	8086_aminopeptidase_P_N-t...fna.awk1.mafft.phy	gcgatcgc	883:890
# _________________________________________________________________________
#
# 1	7455_AtzE_family_amidohyd...fna.awk1.mafft.phy	gcgatcgc	331:338
# 2	7455_AtzE_family_amidohyd...fna.awk1.mafft.phy	gcgatcgc	799:806
# _________________________________________________________________________
#
# 1	6023_S8_family_peptidase.fna.awk1.mafft.phy	gcgatcgc	163:170
# _________________________________________________________________________
#
# 1	6020_zinc_ABC_transporter...fna.awk1.mafft.phy	gcgatcgc	303:310
# _________________________________________________________________________
#
# 1	5426_LL-diaminopimelate_a...fna.awk1.mafft.phy	gcgatcgc	151:158
# 2	5426_LL-diaminopimelate_a...fna.awk1.mafft.phy	gcgatcgc	538:545
# 3	5426_LL-diaminopimelate_a...fna.awk1.mafft.phy	gcgatcgc	865:872
# _________________________________________________________________________
#
# 1	7864_tkt.fna.awk1.mafft.phy	gcgatcgc	197:204
# 2	7864_tkt.fna.awk1.mafft.phy	gcgatcgc	700:707
# 3	7864_tkt.fna.awk1.mafft.phy	gcgatcgc	1546:1553
# _________________________________________________________________________
#
# 1	7662_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	175:182
# 2	7662_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	538:545
# 3	7662_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	1184:1191
# 4	7662_UDP-N-acetylmuramoyl...fna.awk1.mafft.phy	gcgatcgc	1346:1353
# _________________________________________________________________________
#
# 1	8524_queA.fna.awk1.mafft.phy	gcgatcgc	707:714
# _________________________________________________________________________
#
# 1	9534_priA.fna.awk1.mafft.phy	gcgatcgc	459:466
# 2	9534_priA.fna.awk1.mafft.phy	gcgatcgc	1240:1247
# 3	9534_priA.fna.awk1.mafft.phy	gcgatcgc	1328:1335
# _________________________________________________________________________
#
# 1	7741_biopolymer_transport...fna.awk1.mafft.phy	gcgatcgc	457:464
# _________________________________________________________________________
#
# 1	5387_CPBP_family_glutamic...fna.awk1.mafft.phy	gcgatcgc	481:488
# 2	5387_CPBP_family_glutamic...fna.awk1.mafft.phy	gcgatcgc	928:935
# 3	5387_CPBP_family_glutamic...fna.awk1.mafft.phy	gcgatcgc	2195:2202
# 4	5387_CPBP_family_glutamic...fna.awk1.mafft.phy	gcgatcgc	2258:2265
# 5	5387_CPBP_family_glutamic...fna.awk1.mafft.phy	gcgatcgc	2612:2619
# _________________________________________________________________________
#
# 1	5749_phycobilisome_rod-co...fna.awk1.mafft.phy	gcgatcgc	359:366
# _________________________________________________________________________
#
# 1	9872_ABC_transporter_perm...fna.awk1.mafft.phy	gcgatcgc	550:557
# 2	9872_ABC_transporter_perm...fna.awk1.mafft.phy	gcgatcgc	697:704
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	6558_ABC_transporter_subs...fna.awk1.mafft.phy	gcgatcgc	808:815
# _________________________________________________________________________
#
# 1	7802_efflux_RND_transport...fna.awk1.mafft.phy	gcgatcgc	354:361
# 2	7802_efflux_RND_transport...fna.awk1.mafft.phy	gcgatcgc	552:559
# 3	7802_efflux_RND_transport...fna.awk1.mafft.phy	gcgatcgc	622:629
# 4	7802_efflux_RND_transport...fna.awk1.mafft.phy	gcgatcgc	1331:1338
# _________________________________________________________________________
#
# 1	8344_cation_diffusion_fac...fna.awk1.mafft.phy	gcgatcgc	693:700
# 2	8344_cation_diffusion_fac...fna.awk1.mafft.phy	gcgatcgc	764:771
# _________________________________________________________________________
#
# 1	9216_branched-chain_amino...fna.awk1.mafft.phy	gcgatcgc	583:590
# 2	9216_branched-chain_amino...fna.awk1.mafft.phy	gcgatcgc	629:636
# _________________________________________________________________________
#
# 1	9316_pdxA.fna.awk1.mafft.phy	gcgatcgc	337:344
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	9713_glycosyltransferase_...fna.awk1.mafft.phy	gcgatcgc	335:342
# _________________________________________________________________________
#
# 1	6120_magnesium_chelatase_...fna.awk1.mafft.phy	gcgatcgc	314:321
# 2	6120_magnesium_chelatase_...fna.awk1.mafft.phy	gcgatcgc	1279:1286
# 3	6120_magnesium_chelatase_...fna.awk1.mafft.phy	gcgatcgc	2341:2348
# _________________________________________________________________________
#
# 1	8177_MBL_fold_metallo-hyd...fna.awk1.mafft.phy	gcgatcgc	301:308
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	6429_thrB.fna.awk1.mafft.phy	gcgatcgc	319:326
# 2	6429_thrB.fna.awk1.mafft.phy	gcgatcgc	394:401
# 3	6429_thrB.fna.awk1.mafft.phy	gcgatcgc	885:892
# _________________________________________________________________________
#
# _________________________________________________________________________
#
# 1	8343_polyribonucleotide_n...fna.awk1.mafft.phy	gcgatcgc	132:139
# 2	8343_polyribonucleotide_n...fna.awk1.mafft.phy	gcgatcgc	734:741
# 3	8343_polyribonucleotide_n...fna.awk1.mafft.phy	gcgatcgc	838:845
# _________________________________________________________________________
#
# 1	6760_ATP-binding_cassette...fna.awk1.mafft.phy	gcgatcgc	80:87
# 2	6760_ATP-binding_cassette...fna.awk1.mafft.phy	gcgatcgc	461:468
# 3	6760_ATP-binding_cassette...fna.awk1.mafft.phy	gcgatcgc	1627:1634
# _________________________________________________________________________
#
# TOTAL: 479 sitios
